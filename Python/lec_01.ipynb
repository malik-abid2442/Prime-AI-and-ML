# %%
print("Hello World")
# Out:
# Hello World

# %%
name = "Abid" 
age = 30 
PI = 3.14 
word = "arificial intelligence" 
print ("value of PI =", PI)
# Out:
# value of PI = 3.14

# %%
a = 5
b = 3.0
print(a + b)
# Out:
# 8.0

# %%
x = 10
y = float(x)
print(y)  # Output: 10.0
# Out:
# 10.0
