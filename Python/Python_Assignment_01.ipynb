# %% [markdown]
# # Python Assignment

# %%
# Write a program that asks the user for their name and age,then prints a sentence like:
name = input("Enter your name: ")
age = input("Enter your age: ")
print(f"Hello, my name is {name} and I am {age} years old.")
# Out:
# Hello, my name is Abid and I am 22 years old.

# %%
# Question no 2
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)
print("Division:", num1 / num2)
print("Modulus:", num1 % num2)
# Out:
# Addition: 38
# Subtraction: 30
# Multiplication: 136
# Division: 8.5
# Modulus: 2

# %%
num1 = 4
num2 = 3
num3 = 2.0
float_sum = float(num1 + num2 + num3)
print("The average as a float is:", float_sum/3)
# Out:
# The average as a float is: 3.0

# %%
number = '45'
converted_number = int(number)
print(converted_number)  # Output: 45
convert_float = float(number)
print(convert_float)  # Output: 45.0

print(number)
# Out:
# 45
# 45.0
# 45

# %%
x = 10+3*2**2
print(x)  # Output: 22
# Out:
# 22

# %%
val1 = 5
val2 = 6

# Swapping values using tuple unpacking
val1, val2 = val2, val1
print(val1)  # Output: 6
print(val2)  # Output: 5
# Out:
# 6
# 5

# %%
cal = float(input("Enter the value in Celsius: "))
fahrenheit = (cal * 9/5) + 32
print(f"The temperature in Fahrenheit is: {fahrenheit}")
# Out:
# The temperature in Fahrenheit is: 68.0

# %%
radius = 5
area = 3.14 * radius**2
print("The area of the circle is:", area)
# Out:
# The area of the circle is: 78.5

# %%
principal = 1000
rate = 5
time = 3
simple_interest = (principal * rate * time) / 100
print("The simple interest is:", simple_interest)
# Out:
# The simple interest is: 150.0

# %%
dec_num = 12.34567
integral_part = int(dec_num)
print("The integral part is:", integral_part)
fractional_part = dec_num - integral_part
print("The fractional part is:", fractional_part)
# Out:
# The integral part is: 12
# The fractional part is: 0.34567000000000014
