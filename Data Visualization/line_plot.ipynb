# %% [markdown]
# # ***Line Plot***

# %%
import matplotlib.pyplot as plt

# %%
# a simple plot
X = [1, 2, 3, 4]
Y = [5, 6, 7, 8]

plt.plot(X, Y)
plt.show()

# %%
# a simple plot
X = [1, 2, 3, 4]
Y = [5, 6, 7, 8]
plt.title("Line Plot")
plt.xlabel('x-axis')
plt.ylabel('Y-Axis')
plt.plot(X, Y)
plt.legend()
plt.show()
# Out:
# C:\Users\Abid\AppData\Local\Temp\ipykernel_16332\2224950359.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Oscar Winner Movies
oscar_movies = [
    "The Dark Knight", 
    "The Hurt Locker",  
    "The King's Speech", 
    "The Artist",     
    "Argo"
]
oscar_years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232]  # in $M

plt.plot(oscar_years, oscar_revenue)
plt.title("Oscar Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
# Out:
# Text(0, 0.5, 'Revenue(in $M)')

# %%
# Plot multiple
# Non-Oscar Winner Movies
non_oscar_movies = ["Slumdog Millionaire","Avatar","Inception","Hugo","Lincoln"]
non_oscar_years = [2008, 2009, 2010, 2011, 2012]
non_oscar_revenue = [378, 2788, 829, 185, 275]  # in $M

plt.plot(oscar_years, oscar_revenue, label="Oscar Winners")
plt.plot(non_oscar_years, non_oscar_revenue, label="Non-Oscar Winners")
plt.title("Years vs Revenue(in $M)")
plt.xlabel("Years")
plt.ylabel("Revenue(in $M)")
plt.legend()
# plt.legend(loc="upper right")
# plt.legend(loc="upper left")
# plt.legend(loc="center")

# %%
a = [1, 6, 3, 4]
b = [5, 15, 7, 8]

plt.plot(X,Y,"o-r", label='x and y data')
plt.plot(a,b, label = 'a and b data')
plt.legend()
plt.grid()
plt.show()
