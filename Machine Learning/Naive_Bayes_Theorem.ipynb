# %% [markdown]
# # ***Naive Bayes Theorem***

# %%
import pandas as pd
from sklearn.metrics import precision_score, accuracy_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB,MultinomialNB

# %%
import numpy as np

X = np.array([
    [1.2, 3.1],
    [1.8, 2.9],
    [3.0, 4.2],
    [3.2, 4.0]
])

y = np.array(["A", "A", "B", "B"])

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(y)  # A=0, B=1

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.5, stratify=y, random_state=42
)

# %%
model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([1, 0], dtype=int64)

# %%
print("recall score: ", recall_score(y_test, y_pred))
print("accuracy score: ", accuracy_score(y_test, y_pred))
print("precision score: ", precision_score(y_test, y_pred))
# Out:
# recall score:  1.0
# accuracy score:  1.0
# precision score:  1.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.naive_bayes import CategoricalNB

data = {
    "Outlook": ["Sunny", "Sunny", "Overcast", "Rain", "Rain"],
    "Temperature": ["Hot", "Hot", "Hot", "Mild", "Cool"],
    "Humidity": ["High", "High", "High", "High", "Normal"],
    "Wind": ["Weak", "Strong", "Weak", "Weak", "Weak"],
    "PlayTennis": ["No", "No", "Yes", "Yes", "Yes"]
}

df = pd.DataFrame(data)

X = df.drop("PlayTennis", axis=1)
y = df["PlayTennis"]

# Encode categorical features
encoder = OrdinalEncoder()
X_encoded = encoder.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.5, stratify=y, random_state=42
)

model = CategoricalNB()
model.fit(X_train, y_train)

pred = model.predict(X_test)

print("recall score: ", recall_score(y_test, pred))
print("accuracy score: ", accuracy_score(y_test, pred))
print("precision score: ", precision_score(y_test, pred))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 30
#      27 model = CategoricalNB()
#      28 model.fit(X_train, y_train)
# ---> 30 pred = model.predict(X_test)
#      32 print("recall score: ", recall_score(y_test, pred))
#      33 print("accuracy score: ", accuracy_score(y_test, pred))
#
# File c:\Users\Abid\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:106, in _BaseNB.predict(self, X)
#     104 check_is_fitted(self)
#     105 X = self._check_X(X)
# --> 106 jll = self._joint_log_likelihood(X)
#     107 return self.classes_[np.argmax(jll, axis=1)]
#
# File c:\Users\Abid\anaconda3\Lib\site-packages\sklearn\naive_bayes.py:1537, in CategoricalNB._joint_log_likelihood(self, X)
#    1535 for i in range(self.n_features_in_):
#    1536     indices = X[:, i]
# -> 1537     jll += self.feature_log_prob_[i][:, indices].T
#    1538 total_ll = jll + self.class_log_prior_
#    1539 return total_ll
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
