# %% [markdown]
# # ***Pandas Lecture no 01***

# %%
# %pip install pandas
import pandas as pd
data = {'name': ['ali','ahmad','abid'],
        'age':[40,24,22]}
df = pd.DataFrame(data)
df
# Out:
#     name  age
# 0    ali   40
# 1  ahmad   24
# 2   abid   22
